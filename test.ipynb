# %% [markdown]
# 실무사용팁

# %%
#버전 충돌문제 발생할 수 있음
# !pip freeze > requirements.txt

# %%
from num_plus import absum
absum(1,2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from num_plus import absum
#       2 absum(1,2)
#
# ModuleNotFoundError: No module named 'num_plus'
